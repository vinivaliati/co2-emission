# %%
import pandas as pd

from src.config import (
    DADOS_2005_2014,
    DADOS_2015_2019,
    DADOS_2020,
    DADOS_2021,
    DADOS_2022,
    DADOS_2023,
    DADOS_2024,
    DADOS_CONSOLIDADOS,
)

# %%
df_2005_2014 = pd.read_csv(DADOS_2005_2014)
df_2015_2019 = pd.read_csv(DADOS_2015_2019)
df_2020 = pd.read_csv(DADOS_2020)
df_2021 = pd.read_csv(DADOS_2021)
df_2022 = pd.read_csv(DADOS_2022)
df_2023 = pd.read_csv(DADOS_2023, encoding="latin")
df_2024 = pd.read_csv(DADOS_2024, encoding="latin")

# %%
print("====== 2005-2014 ======")
display(df_2005_2014.head(2))

print("====== 2015-2019 ======")
display(df_2015_2019.head(2))

print("====== 2020 ======")
display(df_2020.head(2))

print("====== 2021 ======")
display(df_2021.head(2))

print("====== 2022 ======")
display(df_2022.head(2))

print("====== 2023 ======")
display(df_2023.head(2))

print("====== 2024 ======")
display(df_2024.head(2))
# Out:
# ====== 2005-2014 ======
#    Model year   Make  Model Vehicle class  Engine size (L)  Cylinders  \
# 0        2005  Acura  1.7EL       Compact              1.7          4
# 1        2005  Acura  1.7EL       Compact              1.7          4
#
#   Transmission Fuel type  City (L/100 km)  Highway (L/100 km)  \
# 0           A4         X              9.2                 7.2
# 1           M5         X              9.1                 7.3
#
#    Combined (L/100 km)  Combined (mpg)  CO2 emissions (g/km)  CO2 rating  \
# 0                  8.3              34                   191         NaN
# 1                  8.3              34                   191         NaN
#
#    Smog rating
# 0          NaN
# 1          NaN
# ====== 2015-2019 ======
#    Model year   Make Model Vehicle class  Engine size (L)  Cylinders  \
# 0        2015  Acura   ILX       Compact              2.0          4
# 1        2015  Acura   ILX       Compact              2.4          4
#
#   Transmission Fuel type  City (L/100 km)  Highway (L/100 km)  \
# 0          AS5         Z              9.7                 6.7
# 1           M6         Z             10.8                 7.4
#
#    Combined (L/100 km)  Combined (mpg)  CO2 emissions (g/km)  CO2 rating  \
# 0                  8.3              34                   191         NaN
# 1                  9.3              30                   214         NaN
#
#    Smog rating
# 0          NaN
# 1          NaN
# ====== 2020 ======
#    Model year   Make       Model                 Vehicle class  \
# 0        2020  Acura         ILX                       Compact
# 1        2020  Acura  MDX SH-AWD  Sport utility vehicle: Small
#
#    Engine size (L)  Cylinders Transmission Fuel type  City (L/100 km)  \
# 0              2.4          4          AM8         Z              9.9
# 1              3.5          6          AS9         Z             12.3
#
#    Highway (L/100 km)  Combined (L/100 km)  Combined (mpg)  \
# 0                 7.0                  8.6              33
# 1                 9.2                 10.9              26
#
#    CO2 emissions (g/km)  CO2 rating  Smog rating
# 0                   199           6            3
# 1                   254           4            3
# ====== 2021 ======
#    Model year   Make Model Vehicle class  Engine size (L)  Cylinders  \
# 0        2021  Acura   ILX       Compact              2.4          4
# 1        2021  Acura   NSX    Two-seater              3.5          6
#
#   Transmission Fuel type  City (L/100 km)  Highway (L/100 km)  \
# 0          AM8         Z              9.9                 7.0
# 1          AM9         Z             11.1                10.8
#
#    Combined (L/100 km)  Combined (mpg)  CO2 emissions (g/km)  CO2 rating  \
# 0                  8.6              33                   199           6
# 1                 11.0              26                   256           4
#
#    Smog rating
# 0            3
# 1            3
# ====== 2022 ======
#    Model year   Make       Model                 Vehicle class  \
# 0        2022  Acura         ILX                       Compact
# 1        2022  Acura  MDX SH-AWD  Sport utility vehicle: Small
#
#    Engine size (L)  Cylinders Transmission Fuel type  City (L/100 km)  \
# 0              2.4          4          AM8         Z              9.9
# 1              3.5          6         AS10         Z             12.6
#
#    Highway (L/100 km)  Combined (L/100 km)  Combined (mpg)  \
# 0                 7.0                  8.6              33
# 1                 9.4                 11.2              25
#
#    CO2 emissions (g/km)  CO2 rating  Smog rating
# 0                   200           6            3
# 1                   263           4            5
# ====== 2023 ======
#    Model year   Make           Model Vehicle class  Engine size (L)  \
# 0        2023  Acura         Integra     Full-size              1.5
# 1        2023  Acura  Integra A-SPEC     Full-size              1.5
#
#    Cylinders Transmission Fuel type  City (L/100 km)  Highway (L/100 km)  \
# 0          4          AV7         Z              7.9                 6.3
# 1          4          AV7         Z              8.1                 6.5
#
#    Combined (L/100 km)  Combined (mpg)  CO2 emissions (g/km)  CO2 rating  \
# 0                  7.2              39                   167           6
# 1                  7.4              38                   172           6
#
#    Smog rating
# 0            7
# 1            7
# ====== 2024 ======
#    Model year   Make           Model Vehicle class  Engine size (L)  \
# 0        2024  Acura  Integra A-SPEC     Full-size              1.5
# 1        2024  Acura  Integra A-SPEC     Full-size              1.5
#
#    Cylinders Transmission Fuel type  City (L/100 km)  Highway (L/100 km)  \
# 0          4          AV7         Z              8.1                 6.5
# 1          4           M6         Z              8.9                 6.5
#
#    Combined (L/100 km)  Combined (mpg)  CO2 emissions (g/km)  CO2 rating  \
# 0                  7.4              38                   172           6
# 1                  7.8              36                   181           6
#
#    Smog rating
# 0            7
# 1            6
